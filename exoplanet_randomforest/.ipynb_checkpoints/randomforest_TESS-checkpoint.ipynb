# %%
import os
import json
import numpy as np
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
classification_report, roc_auc_score, average_precision_score,
confusion_matrix, accuracy_score, f1_score
)
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from joblib import dump
import matplotlib.pyplot as plt


RANDOM_STATE = 42

# %% [markdown]
# # Label Mappings and Utility Functions

# %%
def map_labels(series):
    mapping = {"CP": 1, "KP": 1, "FP": 0, "FA": 0, "PC": np.nan, "APC": np.nan}
    mapped = series.astype(str).str.upper().map(mapping)
    return mapped.dropna()

def engineer_features(df):
    df = df.copy()

    for col in df.columns:
        if col.endswith("err1") and col[:-4] + "err2" in df.columns and col[:-4] in df.columns:
            base = col[:-4]
            val = df[base].replace(0, np.nan).abs()
            df[f"relative_uncertainty_{base}"] = (
                df[base + 'err1'].abs() + df[base + 'err2'].abs()
            ) / (2 * val)

        if col.endswith("lim"):
            base = col[:-3]
            df[f"is_limited_{base}"] = (df[col].fillna(0) != 0).astype(int)

    def safe_div(a, b):
        with np.errstate(divide='ignore', invalid='ignore'):
            r = a / b
            return r.replace([np.inf, -np.inf], np.nan)

    derived_features = {
        'transit_snr': ('pl_trandep', lambda df: safe_div(df['pl_trandep'], np.sqrt(df['pl_trandurh']))),
        'planet_star_radius_ratio': ('pl_rade', lambda df: safe_div(df['pl_rade'], df['st_rad'])),
        'flux_temp_ratio': ('pl_insol', lambda df: safe_div(df['pl_insol'], df['st_teff'])),
        'period_over_duration': ('pl_orbper', lambda df: safe_div(df['pl_orbper'], df['pl_trandurh'])),
        'depth_over_tmag': ('pl_trandep', lambda df: safe_div(df['pl_trandep'], df['st_tmag']))
    }

    for name, (ref, func) in derived_features.items():
        try:
            if ref in df.columns:
                df[name] = func(df)
        except Exception:
            pass

    return df

# %% [markdown]
# # ML pipeline

# %%
def build_pipeline(best_params=None):
    if best_params is None:
        best_params = {
            'rf__n_estimators': 300,
            'rf__max_depth': None,
            'rf__min_samples_split': 2,
            'rf__max_features': 'sqrt'
        }

    return ImbPipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler()),
        ('smote', SMOTE(random_state=RANDOM_STATE)),
        ('rf', RandomForestClassifier(
            n_estimators=best_params['rf__n_estimators'],
            max_depth=best_params['rf__max_depth'],
            min_samples_split=best_params['rf__min_samples_split'],
            max_features=best_params['rf__max_features'],
            class_weight='balanced',
            random_state=RANDOM_STATE,
            n_jobs=-1
        ))
    ])

# %% [markdown]
# # Visualization Function

# %%
def plot_results(y_test, y_prob, feature_importances, outdir, show_inline=True):
    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc_score(y_test, y_prob):.3f})")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(outdir, 'roc_curve.png'))
    if show_inline:
        plt.show()
    plt.close()

    # Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_test, y_prob)
    plt.figure()
    plt.plot(recall, precision, label=f"PR Curve (AUC = {average_precision_score(y_test, y_prob):.3f})")
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(outdir, 'precision_recall_curve.png'))
    if show_inline:
        plt.show()
    plt.close()

    # Feature Importances
    plt.figure(figsize=(8, 6))
    feature_importances.head(20).sort_values().plot(kind='barh')
    plt.title('Top 20 Feature Importances')
    plt.xlabel('Importance')
    plt.tight_layout()
    plt.savefig(os.path.join(outdir, 'feature_importance.png'))
    if show_inline:
        plt.show()
    plt.close()

# %% [markdown]
# # Objective Function for Optuna

# %%
def objective(trial, X_train, y_train):
    n_estimators = trial.suggest_int('rf__n_estimators', 100, 600)
    max_depth = trial.suggest_categorical('rf__max_depth', [None, 10, 20, 30])
    min_samples_split = trial.suggest_int('rf__min_samples_split', 2, 10)
    max_features = trial.suggest_categorical('rf__max_features', ['sqrt', 'log2'])

    pipeline = build_pipeline({
        'rf__n_estimators': n_estimators,
        'rf__max_depth': max_depth,
        'rf__min_samples_split': min_samples_split,
        'rf__max_features': max_features
    })

    scores = cross_val_score(
        pipeline, X_train, y_train,
        cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE),
        scoring='average_precision', n_jobs=-1
    )

    return np.mean(scores)

# %%
def main(csv_path="tess.csv", outdir=os.path.expanduser("~/Desktop/space_apps_hackathon"), visualize=True):
    os.makedirs(outdir, exist_ok=True)

    print(f"[INFO] Loading dataset from: {csv_path}")
    df = pd.read_csv(csv_path)

    if 'tfopwg_disp' not in df.columns:
        raise ValueError("Expected 'tfopwg_disp' column for classification target.")

    y = map_labels(df['tfopwg_disp'])
    df = df.loc[y.index]

    print("[INFO] Engineering features...")
    X = df.drop(columns=['tfopwg_disp'], errors='ignore')
    X = engineer_features(X)

    numeric_cols = X.select_dtypes(include=[np.number]).columns
    X = X[numeric_cols]
    X = X.dropna(axis=1, how='all')

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=y
    )

    pipe = build_pipeline()

    param_grid = {
        'rf__n_estimators': [200, 300],
        'rf__max_depth': [10, None],
        'rf__min_samples_split': [2],
        'rf__max_features': ['sqrt']
    }

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

    grid = GridSearchCV(pipe, param_grid, cv=cv, scoring='average_precision', n_jobs=-1, verbose=2)
    grid.fit(X_train, y_train)

    best_model = grid.best_estimator_
    y_pred = best_model.predict(X_test)
    y_prob = best_model.predict_proba(X_test)[:, 1]

    metrics = {
        'roc_auc': roc_auc_score(y_test, y_prob),
        'pr_auc': average_precision_score(y_test, y_prob),
        'accuracy': accuracy_score(y_test, y_pred),
        'f1_score': f1_score(y_test, y_pred),
        'confusion_matrix': confusion_matrix(y_test, y_pred).tolist(),
        'classification_report': classification_report(y_test, y_pred, output_dict=True),
        'best_params': grid.best_params_
    }

    feature_importances = pd.Series(
        best_model.named_steps['rf'].feature_importances_, index=X.columns
    ).sort_values(ascending=False)
    feature_importances.to_csv(os.path.join(outdir, 'feature_importance.csv'))

    with open(os.path.join(outdir, 'metrics.json'), 'w') as f:
        json.dump(metrics, f, indent=2)

    dump(best_model, os.path.join(outdir, 'rf_pipeline.joblib'))

    print("\n=== MODEL TRAINING COMPLETE ===")
    print(json.dumps(metrics, indent=2))

    if visualize:
        print("[INFO] Generating plots...")
        plot_results(y_test, y_prob, feature_importances, outdir,show_inline=True)
        print(f"[INFO] Plots saved in {outdir}")

if __name__ == "__main__":
    main()
# Out:
# [I 2025-10-05 01:57:33,736] A new study created in memory with name: no-name-56fdf11b-ba65-435f-b74a-dd2dcea95d3e
# [INFO] Loading dataset from: tess.csv
# [INFO] Engineering features...
# [INFO] Starting Bayesian Optimization with Optuna...
# [I 2025-10-05 01:57:39,229] Trial 0 finished with value: 0.9306922980747231 and parameters: {'rf__n_estimators': 530, 'rf__max_depth': 10, 'rf__min_samples_split': 7, 'rf__max_features': 'log2'}. Best is trial 0 with value: 0.9306922980747231.
# [I 2025-10-05 01:57:42,219] Trial 1 finished with value: 0.9329698977382186 and parameters: {'rf__n_estimators': 170, 'rf__max_depth': None, 'rf__min_samples_split': 4, 'rf__max_features': 'sqrt'}. Best is trial 1 with value: 0.9329698977382186.
# [I 2025-10-05 01:57:45,728] Trial 2 finished with value: 0.9307192104231332 and parameters: {'rf__n_estimators': 508, 'rf__max_depth': 10, 'rf__min_samples_split': 7, 'rf__max_features': 'log2'}. Best is trial 1 with value: 0.9329698977382186.
# [I 2025-10-05 01:57:46,716] Trial 3 finished with value: 0.9297566127597694 and parameters: {'rf__n_estimators': 158, 'rf__max_depth': 10, 'rf__min_samples_split': 9, 'rf__max_features': 'log2'}. Best is trial 1 with value: 0.9329698977382186.
# [I 2025-10-05 01:57:49,365] Trial 4 finished with value: 0.9333567426007511 and parameters: {'rf__n_estimators': 402, 'rf__max_depth': 20, 'rf__min_samples_split': 7, 'rf__max_features': 'sqrt'}. Best is trial 4 with value: 0.9333567426007511.
# [I 2025-10-05 01:57:51,000] Trial 5 finished with value: 0.9320630763428526 and parameters: {'rf__n_estimators': 249, 'rf__max_depth': 20, 'rf__min_samples_split': 10, 'rf__max_features': 'log2'}. Best is trial 4 with value: 0.9333567426007511.
# [I 2025-10-05 01:57:52,589] Trial 6 finished with value: 0.933070736332466 and parameters: {'rf__n_estimators': 213, 'rf__max_depth': 10, 'rf__min_samples_split': 2, 'rf__max_features': 'sqrt'}. Best is trial 4 with value: 0.9333567426007511.
# [I 2025-10-05 01:57:56,123] Trial 7 finished with value: 0.9325316320916898 and parameters: {'rf__n_estimators': 565, 'rf__max_depth': None, 'rf__min_samples_split': 9, 'rf__max_features': 'sqrt'}. Best is trial 4 with value: 0.9333567426007511.
# [I 2025-10-05 01:57:58,348] Trial 8 finished with value: 0.9330837741010362 and parameters: {'rf__n_estimators': 387, 'rf__max_depth': None, 'rf__min_samples_split': 7, 'rf__max_features': 'log2'}. Best is trial 4 with value: 0.9333567426007511.
# [I 2025-10-05 01:58:01,822] Trial 9 finished with value: 0.9333397650553502 and parameters: {'rf__n_estimators': 532, 'rf__max_depth': 30, 'rf__min_samples_split': 7, 'rf__max_features': 'sqrt'}. Best is trial 4 with value: 0.9333567426007511.
# [I 2025-10-05 01:58:04,329] Trial 10 finished with value: 0.9343153518913357 and parameters: {'rf__n_estimators': 382, 'rf__max_depth': 20, 'rf__min_samples_split': 5, 'rf__max_features': 'sqrt'}. Best is trial 10 with value: 0.9343153518913357.
# [I 2025-10-05 01:58:06,906] Trial 11 finished with value: 0.9343746440763526 and parameters: {'rf__n_estimators': 378, 'rf__max_depth': 20, 'rf__min_samples_split': 5, 'rf__max_features': 'sqrt'}. Best is trial 11 with value: 0.9343746440763526.
# [I 2025-10-05 01:58:09,053] Trial 12 finished with value: 0.9341967774443409 and parameters: {'rf__n_estimators': 304, 'rf__max_depth': 20, 'rf__min_samples_split': 4, 'rf__max_features': 'sqrt'}. Best is trial 11 with value: 0.9343746440763526.
# [I 2025-10-05 01:58:12,155] Trial 13 finished with value: 0.9348877427491054 and parameters: {'rf__n_estimators': 439, 'rf__max_depth': 20, 'rf__min_samples_split': 5, 'rf__max_features': 'sqrt'}. Best is trial 13 with value: 0.9348877427491054.
# [I 2025-10-05 01:58:15,418] Trial 14 finished with value: 0.935470547446673 and parameters: {'rf__n_estimators': 468, 'rf__max_depth': 20, 'rf__min_samples_split': 2, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:19,060] Trial 15 finished with value: 0.9354250082479272 and parameters: {'rf__n_estimators': 460, 'rf__max_depth': 30, 'rf__min_samples_split': 2, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:22,723] Trial 16 finished with value: 0.9354394157085458 and parameters: {'rf__n_estimators': 462, 'rf__max_depth': 30, 'rf__min_samples_split': 2, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:27,282] Trial 17 finished with value: 0.9354449346603527 and parameters: {'rf__n_estimators': 591, 'rf__max_depth': 30, 'rf__min_samples_split': 3, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:31,747] Trial 18 finished with value: 0.9353721076842275 and parameters: {'rf__n_estimators': 585, 'rf__max_depth': 30, 'rf__min_samples_split': 3, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:36,449] Trial 19 finished with value: 0.9354626328055973 and parameters: {'rf__n_estimators': 592, 'rf__max_depth': 30, 'rf__min_samples_split': 3, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:38,811] Trial 20 finished with value: 0.9353648343002865 and parameters: {'rf__n_estimators': 325, 'rf__max_depth': 30, 'rf__min_samples_split': 3, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:43,105] Trial 21 finished with value: 0.9354227206124435 and parameters: {'rf__n_estimators': 587, 'rf__max_depth': 30, 'rf__min_samples_split': 3, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:46,928] Trial 22 finished with value: 0.9346057509818415 and parameters: {'rf__n_estimators': 488, 'rf__max_depth': 30, 'rf__min_samples_split': 4, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:51,230] Trial 23 finished with value: 0.9352189403539874 and parameters: {'rf__n_estimators': 553, 'rf__max_depth': 30, 'rf__min_samples_split': 3, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:54,862] Trial 24 finished with value: 0.9351024802727166 and parameters: {'rf__n_estimators': 491, 'rf__max_depth': 30, 'rf__min_samples_split': 2, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:58:59,287] Trial 25 finished with value: 0.9345263858573734 and parameters: {'rf__n_estimators': 600, 'rf__max_depth': 30, 'rf__min_samples_split': 4, 'rf__max_features': 'sqrt'}. Best is trial 14 with value: 0.935470547446673.
# [I 2025-10-05 01:59:02,448] Trial 26 finished with value: 0.9363375976365085 and parameters: {'rf__n_estimators': 437, 'rf__max_depth': 20, 'rf__min_samples_split': 3, 'rf__max_features': 'log2'}. Best is trial 26 with value: 0.9363375976365085.
# [I 2025-10-05 01:59:05,466] Trial 27 finished with value: 0.934029830676568 and parameters: {'rf__n_estimators': 414, 'rf__max_depth': 20, 'rf__min_samples_split': 6, 'rf__max_features': 'log2'}. Best is trial 26 with value: 0.9363375976365085.
# [I 2025-10-05 01:59:09,271] Trial 28 finished with value: 0.9346803085795121 and parameters: {'rf__n_estimators': 442, 'rf__max_depth': 20, 'rf__min_samples_split': 2, 'rf__max_features': 'log2'}. Best is trial 26 with value: 0.9363375976365085.
# [I 2025-10-05 01:59:10,393] Trial 29 finished with value: 0.9304008848054963 and parameters: {'rf__n_estimators': 109, 'rf__max_depth': 20, 'rf__min_samples_split': 6, 'rf__max_features': 'log2'}. Best is trial 26 with value: 0.9363375976365085.
# [INFO] Best Parameters: {'rf__n_estimators': 437, 'rf__max_depth': 20, 'rf__min_samples_split': 3, 'rf__max_features': 'log2'}
# === MODEL TRAINING COMPLETE ===
# {
#   "roc_auc": 0.9502325722798164,
#   "pr_auc": 0.9519488408193348,
#   "accuracy": 0.8947368421052632,
#   "f1_score": 0.8924302788844621,
#   "confusion_matrix": [
#     [
#       235,
#       24
#     ],
#     [
#       30,
#       224
#     ]
#   ],
#   "classification_report": {
#     "0.0": {
#       "precision": 0.8867924528301887,
#       "recall": 0.9073359073359073,
#       "f1-score": 0.8969465648854962,
#       "support": 259.0
#     },
#     "1.0": {
#       "precision": 0.9032258064516129,
#       "recall": 0.8818897637795275,
#       "f1-score": 0.8924302788844621,
#       "support": 254.0
#     },
#     "accuracy": 0.8947368421052632,
#     "macro avg": {
#       "precision": 0.8950091296409008,
#       "recall": 0.8946128355577174,
#       "f1-score": 0.8946884218849791,
#       "support": 513.0
#     },
#     "weighted avg": {
#       "precision": 0.8949290450715955,
#       "recall": 0.8947368421052632,
#       "f1-score": 0.8947104310760173,
#       "support": 513.0
#     }
#   },
#   "best_params": {
#     "rf__n_estimators": 437,
#     "rf__max_depth": 20,
#     "rf__min_samples_split": 3,
#     "rf__max_features": "log2"
#   }
# }
